# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ankr = pd.read_csv('/content/polygon_ankr.csv')
subgraph = pd.read_csv('/content/polygon_subgraph.csv')

# %%
ankr.head()
# Out:
#                                      contract
# 0  0x014ac2a53aa6fba4dcd93fde6d3c787b79a1a6e6
# 1  0x019ba0325f1988213d448b3472fa1cf8d07618d7
# 2  0x022df0b3341b3a0157eea97dd024a93f7496d631
# 3  0x02a3e4184b145ee64a6df3c561a3c0c6e2f23dfa
# 4  0x032d86f50ee9c0c361f268bd7c08013465e29968

# %%
subgraph.head()
# Out:
#                                  pool_address
# 0  0xac4494e30a85369e332bdb5230d6d694d4259dbc
# 1  0x55caabb0d2b704fd0ef8192a7e35d8837e678207
# 2  0x479e1b71a702a595e19b6d5932cd5c863ab57ee0
# 3  0x7b925e617aefd7fb3a93abe3a701135d7a1ba710
# 4  0xae81fac689a1b4b1e06e7ef4a2ab4cd8ac0a087d

# %%
import time
from tqdm import tqdm

rows = []
pool = subgraph.pool_address

for i in tqdm(range(0, len(ankr))):
    if ankr.contract[i] not in list(pool):
        rows.append({'unfound': ankr.contract[i]})

extra = pd.DataFrame(rows)
# Out:
# 100%|██████████| 2977/2977 [00:04<00:00, 665.23it/s]

# %%
extra
# Out:
#                                          unfound
# 0     0x019ba0325f1988213d448b3472fa1cf8d07618d7
# 1     0x032d86f50ee9c0c361f268bd7c08013465e29968
# 2     0x04e2dc96afecdf72221882e1cee039cab4d443e0
# 3     0x0a8a3cb9a21c893a207826e76125ef6faaad99ec
# 4     0x0f44517ac321dc0d2bf13bc3728c18577d9af6d4
# ...                                          ...
# 1343  0xf0e020a4675b4776a3bb22843494ce6b42ebfa0a
# 1344  0xf3eb2f17eafbf35e92c965a954c6e7693187057d
# 1345  0xfb5e6eb1c844b04924121fb0bf6b9623fc0b9f4d
# 1346  0xfc300a58e46089aa6b3ed78fa8fda4fb36614d3f
# 1347  0xff3a26198c875b5fb1bc68ae18e82d633c351049
#
# [1348 rows x 1 columns]
