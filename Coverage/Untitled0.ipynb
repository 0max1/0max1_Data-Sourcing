# %%
import pandas as pd
import numpy as np

# %%
missing = pd.read_csv('/content/pancakeswap.csv')
adding = pd.read_csv('/content/pancake_all.csv')

# %%
import time
from tqdm import tqdm

rows = []
pool = adding.pool_address

for i in tqdm(range(0, len(missing))):
    if missing.pancakeswap[i] not in list(pool):
        rows.append({'unfound': missing.pancakeswap[i]})

extra = pd.DataFrame(rows)
# Out:
# 100%|██████████| 2880/2880 [00:07<00:00, 371.33it/s]

# %%
extra
# Out:
#                                          unfound
# 0     0x65f2ee8b6c52a263b39f1ffc8f97d4b38f14e96d
# 1     0x3cee24ed4e74f1f4aa9c8a75cc693847ef8e528f
# 2     0xbc1e965658453a3e6ac1104f1932e202a3ea6ab4
# 3     0x57528d1cf2b14bb35781df41099f10cd927ff026
# 4     0xbe45115c75e7ce908fabc9584e6c18c4a74aa37f
# ...                                          ...
# 2868  0xf66d7e935a9f86dd890d909c801a54b2107c73a1
# 2869  0xf992b3ff46680112b14f9715e0d2b85ec49ccce0
# 2870  0xfe5cf42adf6c50e1b04e108ad78b5525ea1a6c93
# 2871  0xfe9e722de0ce24fc13ffde8b5b14aef8c5a3551e
# 2872  0xff1838309b6b9727054e2dc52eebf9bf3573bded
#
# [2873 rows x 1 columns]
